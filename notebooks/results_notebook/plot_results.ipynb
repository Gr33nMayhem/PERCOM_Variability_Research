# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
from sklearn.metrics import confusion_matrix
import seaborn as sns

# %%
run_log_directory = '../../data/Run_logs/'
devices = ['empatica-left',
           'empatica-right',
           'bluesense-LUA',
           'bluesense-LWR',
           'bluesense-RUA',
           'bluesense-RWR1',
           'bluesense-RWR2',
           'bluesense-TRS',
           'maxim-red',
           'maxim-green', ]
for device in devices:
    parent_directory = run_log_directory + device + '/logs/'
    if not os.path.exists(parent_directory):
        continue
    # get all the sub directories in the parent directory
    sub_directories = os.listdir(parent_directory)
    for directory in sub_directories:
        cv_directories = os.listdir(parent_directory + directory + '/')
        for cv_directory in cv_directories:
            # check if a directory
            if not os.path.isdir(parent_directory + directory + '/' + cv_directory):
                continue
            # open the csv file prediction_result_ and read the data
            csv_file = parent_directory + directory + '/' + cv_directory + '/prediction_result_' + device + '.csv'
            # open with pandas
            df = pd.read_csv(csv_file)
            # get the prediction result
            preds = df['preds'].values
            # get the ground truth
            trues = df['trues'].values

            # plot a confusion matrix
            cm = confusion_matrix(trues, preds)
            # plot the confusion matrix using seaborn
            sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
            plt.xlabel('Predicted')
            plt.ylabel('True')
            plt.title('Confusion Matrix for ' + device)
            plt.savefig(parent_directory + directory + '/' + cv_directory + '/confusion_matrix_' + device + '.png')
            plt.close()
            print(directory)
            print (cv_directory)
            # print the accuracy
            print('Accuracy for ' + device + ' is ' + str(np.sum(preds == trues) / len(preds)))
            # print the precision
            print('Precision for ' + device + ' is ' + str(np.sum((preds == 1) & (trues == 1)) / np.sum(preds == 1)))
            # print the recall
            print('Recall for ' + device + ' is ' + str(np.sum((preds == 1) & (trues == 1)) / np.sum(trues == 1)))
            # print the f1 score
            print('F1 score for ' + device + ' is ' + str(2 * np.sum((preds == 1) & (trues == 1)) / (np.sum(preds == 1) + np.sum(trues == 1))))
            print('-----------------------------------------')
# Out:
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_0
# Accuracy for bluesense-RWR1 is 0.7312793307488268
# Precision for bluesense-RWR1 is 0.7659930212271009
# Recall for bluesense-RWR1 is 0.935043038423995
# F1 score for bluesense-RWR1 is 0.8421178821178821
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_1
# Accuracy for bluesense-RWR1 is 0.8214127382887543
# Precision for bluesense-RWR1 is 0.8307427888208041
# Recall for bluesense-RWR1 is 0.9865116691809389
# F1 score for bluesense-RWR1 is 0.9019512393006369
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_2
# Accuracy for bluesense-RWR1 is 0.9682972313871755
# Precision for bluesense-RWR1 is 0.9668046214864632
# Recall for bluesense-RWR1 is 0.9949423247559893
# F1 score for bluesense-RWR1 is 0.980671680951548
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_3
# Accuracy for bluesense-RWR1 is 0.7137433561123766
# Precision for bluesense-RWR1 is 0.7141949825341378
# Recall for bluesense-RWR1 is 0.9978702635548851
# F1 score for bluesense-RWR1 is 0.8325312800769971
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_4
# Accuracy for bluesense-RWR1 is 0.9939230249831195
# Precision for bluesense-RWR1 is 0.9924182315084192
# Recall for bluesense-RWR1 is 0.9988464951197871
# F1 score for bluesense-RWR1 is 0.9956219873524079
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_5
# Accuracy for bluesense-RWR1 is 0.9506284202297192
# Precision for bluesense-RWR1 is 0.9484164449403485
# Recall for bluesense-RWR1 is 0.9804791481810116
# F1 score for bluesense-RWR1 is 0.9641813184416038
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_6
# Accuracy for bluesense-RWR1 is 0.6562116376135526
# Precision for bluesense-RWR1 is 0.6803487336133385
# Recall for bluesense-RWR1 is 0.948708847280149
# F1 score for bluesense-RWR1 is 0.7924248600970982
# -----------------------------------------
# attend_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_grufilter_128_Regu_False_wavelearnble_False
# cv_7
# Accuracy for bluesense-RWR1 is 0.9339922132374963
# Precision for bluesense-RWR1 is 0.9161755075311068
# Recall for bluesense-RWR1 is 0.9930789707187223
# F1 score for bluesense-RWR1 is 0.9530784297028017
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_0
# Accuracy for bluesense-RWR1 is 0.7330476773447596
# Precision for bluesense-RWR1 is 0.7604994324631101
# Recall for bluesense-RWR1 is 0.9512822788179963
# F1 score for bluesense-RWR1 is 0.8452592154543662
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_1
# Accuracy for bluesense-RWR1 is 0.8031624057928181
# Precision for bluesense-RWR1 is 0.8275599543205177
# Recall for bluesense-RWR1 is 0.9645931315999645
# F1 score for bluesense-RWR1 is 0.8908375676118669
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_2
# Accuracy for bluesense-RWR1 is 0.9595466934442691
# Precision for bluesense-RWR1 is 0.955652025876745
# Recall for bluesense-RWR1 is 0.9961845607808341
# F1 score for bluesense-RWR1 is 0.9754974367886002
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_3
# Accuracy for bluesense-RWR1 is 0.7210832700582132
# Precision for bluesense-RWR1 is 0.7191312679655062
# Recall for bluesense-RWR1 is 0.999023870795989
# F1 score for bluesense-RWR1 is 0.8362798989748923
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_4
# Accuracy for bluesense-RWR1 is 0.9988950954514763
# Precision for bluesense-RWR1 is 0.9984053862508859
# Recall for bluesense-RWR1 is 1.0
# F1 score for bluesense-RWR1 is 0.9992020569199397
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_5
# Accuracy for bluesense-RWR1 is 0.9823200432978532
# Precision for bluesense-RWR1 is 0.9919325923269989
# Recall for bluesense-RWR1 is 0.9818988464951198
# F1 score for bluesense-RWR1 is 0.9868902167127441
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_6
# Accuracy for bluesense-RWR1 is 0.6597716670758654
# Precision for bluesense-RWR1 is 0.6815242201369516
# Recall for bluesense-RWR1 is 0.9538557103558435
# F1 score for bluesense-RWR1 is 0.7950149772567583
# -----------------------------------------
# deepconvlstm_data_harvar_seed_1_windowsize_128_waveFilter_False_Fscaling_1_cvfilter_64_lstmfilter_128_Regu_False_wavelearnble_False
# cv_7
# Accuracy for bluesense-RWR1 is 0.9443545971847859
# Precision for bluesense-RWR1 is 0.9284826386011437
# Recall for bluesense-RWR1 is 0.9941437444543034
# F1 score for bluesense-RWR1 is 0.9601919698333119
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_0
# Accuracy for bluesense-RWR1 is 0.7571243963816908
# Precision for bluesense-RWR1 is 0.766588170106663
# Recall for bluesense-RWR1 is 0.9821634572721626
# F1 score for bluesense-RWR1 is 0.8610884194966352
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_1
# Accuracy for bluesense-RWR1 is 0.7795182503324959
# Precision for bluesense-RWR1 is 0.8232539992196645
# Recall for bluesense-RWR1 is 0.936196645665099
# F1 score for bluesense-RWR1 is 0.8761003155621989
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_2
# Accuracy for bluesense-RWR1 is 0.980131975326352
# Precision for bluesense-RWR1 is 0.9784141352598137
# Recall for bluesense-RWR1 is 0.9974267968056788
# F1 score for bluesense-RWR1 is 0.9878289907289424
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_3
# Accuracy for bluesense-RWR1 is 0.7312072892938497
# Precision for bluesense-RWR1 is 0.726527715041621
# Recall for bluesense-RWR1 is 0.9991126098145354
# F1 score for bluesense-RWR1 is 0.8412911903160726
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_4
# Accuracy for bluesense-RWR1 is 0.9819532257074458
# Precision for bluesense-RWR1 is 0.9745762711864406
# Recall for bluesense-RWR1 is 1.0
# F1 score for bluesense-RWR1 is 0.9871244635193133
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_5
# Accuracy for bluesense-RWR1 is 0.9816585483192014
# Precision for bluesense-RWR1 is 0.9848766250994959
# Recall for bluesense-RWR1 is 0.9881100266193434
# F1 score for bluesense-RWR1 is 0.9864906763520397
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_6
# Accuracy for bluesense-RWR1 is 0.6705745150994353
# Precision for bluesense-RWR1 is 0.68653603034134
# Recall for bluesense-RWR1 is 0.9637944804330464
# F1 score for bluesense-RWR1 is 0.8018752999372439
# -----------------------------------------
# tinyhar_data_harvar_seed_1_windowsize_128_cvfilter_20_CI_attn_CA_FC_TI_lstm_TA_tnaive
# cv_7
# Accuracy for bluesense-RWR1 is 0.9653788559448937
# Precision for bluesense-RWR1 is 0.9557544757033248
# Recall for bluesense-RWR1 is 0.9947648624667258
# F1 score for bluesense-RWR1 is 0.9748695652173913
# -----------------------------------------
